# %% [markdown]
# ### Dependencies and Setup

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import requests

import time

from pprint import pprint

import openweathermapy.core as owm

from api_keys import api_key

from citipy import citipy

# %% [markdown]
# ### Set Range of latitudes and longitudes

# %%
lat_range = (-90, 90)

lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []

cities = []
# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 632

# %% [markdown]
# ### Create an empty dataframe with cities column to store weather variables

# %%
cities_data = pd.DataFrame(cities)

cities_data = cities_data.rename(columns={0:"City"})

cities_data["Temperature"] = ""

cities_data["Lat"] = ""

cities_data["Lon"] = ""

cities_data["Humidity"] = ""

cities_data["Cloudiness"] = ""

cities_data["Wind Speed"] = ""


cities_data.head()
# Out:
#              City Temperature Lat Lon Humidity Cloudiness Wind Speed
# 0     new norfolk
# 1         hualmay
# 2           ejura
# 3          zhuhai
# 4  vestmannaeyjar

# %% [markdown]
# ### Build URL inputs for API Calls

# %%
units = "imperial"

base_url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{base_url}appid={api_key}&units={units}&q="

# %% [markdown]
# ### Create empty list for each weather variable

# %%
lat = []

lon = []

temp_max = []

humidity = []

clouds = []

wind_speed = []

cities = []

dates = []

countries = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
record_count = 1

set_count = 1

for index, row in cities_data.iterrows():
    
    if (index % 50 == 0 and index >=50):
        
        set_count +=1
        
        record_count = 0
    
    city = row["City"]
   
    final_query_url = query_url+city
    
    
    print("Processing Record %s of Set %s | %s" % (record_count, set_count,city))
    
    record_count +=1
   
    response = requests.get(final_query_url).json()
    
    try:

        cities.append(response['name'])
        
        dates.append(response['dt'])
        
        countries.append(response['sys']['country'])
        
        lon.append(response['coord']['lon'])
        
        lat.append(response['coord']['lat'])
        
        temp_max.append(response['main']['temp_max'])
        
        humidity.append(response['main']['humidity'])
        
        clouds.append(response['clouds']['all'])
        
        wind_speed.append(response['wind']['speed'])
        
    except (KeyError, IndexError):
        
        print("Data unavilable...skipping.")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | ejura
# Processing Record 4 of Set 1 | zhuhai
# Processing Record 5 of Set 1 | vestmannaeyjar
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | matara
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | ust-nera
# Processing Record 14 of Set 1 | amderma
# Data unavilable...skipping.
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | madimba
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | iznoski
# Processing Record 22 of Set 1 | pudozh
# Processing Record 23 of Set 1 | belushya guba
# Data unavilable...skipping.
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | nchelenge
# Processing Record 26 of Set 1 | goderich
# Processing Record 27 of Set 1 | pangody
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | beyneu
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | los llanos de aridane
# Processing Record 32 of Set 1 | nioro
# Processing Record 33 of Set 1 | edgewater
# Processing Record 34 of Set 1 | taolanaro
# Data unavilable...skipping.
# Processing Record 35 of Set 1 | dengzhou
# Processing Record 36 of Set 1 | dudinka
# Processing Record 37 of Set 1 | vao
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | sinnamary
# Processing Record 41 of Set 1 | brownwood
# Processing Record 42 of Set 1 | buzmeyin
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | boysun
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | atbasar
# Processing Record 47 of Set 1 | rjukan
# Processing Record 48 of Set 1 | magdagachi
# Processing Record 49 of Set 1 | teguise
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 0 of Set 2 | norman wells
# Processing Record 1 of Set 2 | thinadhoo
# Processing Record 2 of Set 2 | yarkovo
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | narsaq
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | hollola
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | nguiu
# Data unavilable...skipping.
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | twin falls
# Processing Record 14 of Set 2 | kualakapuas
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | bin qirdan
# Processing Record 17 of Set 2 | srednekolymsk
# Processing Record 18 of Set 2 | imeni zhelyabova
# Processing Record 19 of Set 2 | nizhniy tsasuchey
# Processing Record 20 of Set 2 | meulaboh
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | mys shmidta
# Data unavilable...skipping.
# Processing Record 23 of Set 2 | sarangani
# Processing Record 24 of Set 2 | barentsburg
# Data unavilable...skipping.
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | avera
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | illoqqortoormiut
# Data unavilable...skipping.
# Processing Record 32 of Set 2 | sofiysk
# Data unavilable...skipping.
# Processing Record 33 of Set 2 | roma
# Processing Record 34 of Set 2 | santiago del estero
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 2 | milingimbi
# Data unavilable...skipping.
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | roald
# Processing Record 42 of Set 2 | meredith
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | palana
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | pangnirtung
# Processing Record 47 of Set 2 | soyo
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | kollumerland
# Data unavilable...skipping.
# Processing Record 0 of Set 3 | sentyabrskiy
# Data unavilable...skipping.
# Processing Record 1 of Set 3 | antofagasta
# Processing Record 2 of Set 3 | oranjestad
# Processing Record 3 of Set 3 | ciudad real
# Processing Record 4 of Set 3 | maceio
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | fare
# Processing Record 7 of Set 3 | asau
# Data unavilable...skipping.
# Processing Record 8 of Set 3 | hazorasp
# Processing Record 9 of Set 3 | kahului
# Processing Record 10 of Set 3 | ratnagiri
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | luanda
# Processing Record 14 of Set 3 | sorgun
# Processing Record 15 of Set 3 | kamenskoye
# Data unavilable...skipping.
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | huamachuco
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | haapu
# Data unavilable...skipping.
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | boende
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | rio gallegos
# Processing Record 27 of Set 3 | vila franca do campo
# Processing Record 28 of Set 3 | pinawa
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | disna
# Data unavilable...skipping.
# Processing Record 31 of Set 3 | matelandia
# Processing Record 32 of Set 3 | nueve de julio
# Processing Record 33 of Set 3 | vaitape
# Processing Record 34 of Set 3 | iqaluit
# Processing Record 35 of Set 3 | aranos
# Processing Record 36 of Set 3 | cody
# Processing Record 37 of Set 3 | kalmunai
# Processing Record 38 of Set 3 | lukovetskiy
# Processing Record 39 of Set 3 | half moon bay
# Processing Record 40 of Set 3 | kyle of lochalsh
# Data unavilable...skipping.
# Processing Record 41 of Set 3 | adrar
# Processing Record 42 of Set 3 | liwale
# Processing Record 43 of Set 3 | inuvik
# Processing Record 44 of Set 3 | qaqortoq
# Processing Record 45 of Set 3 | saint-augustin
# Processing Record 46 of Set 3 | arlit
# Processing Record 47 of Set 3 | atar
# Processing Record 48 of Set 3 | somerset
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 0 of Set 4 | tsihombe
# Data unavilable...skipping.
# Processing Record 1 of Set 4 | fukue
# Processing Record 2 of Set 4 | beringovskiy
# Processing Record 3 of Set 4 | luebo
# Processing Record 4 of Set 4 | greenfield
# Processing Record 5 of Set 4 | laguna
# Processing Record 6 of Set 4 | itamarandiba
# Processing Record 7 of Set 4 | sangar
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | matagami
# Processing Record 10 of Set 4 | yeppoon
# Processing Record 11 of Set 4 | bakaly
# Processing Record 12 of Set 4 | maldonado
# Processing Record 13 of Set 4 | melchor de mencos
# Processing Record 14 of Set 4 | pokosnoye
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | kapaa
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | bam
# Processing Record 20 of Set 4 | naze
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | tumannyy
# Data unavilable...skipping.
# Processing Record 23 of Set 4 | scarborough
# Processing Record 24 of Set 4 | labutta
# Data unavilable...skipping.
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | kodiak
# Processing Record 28 of Set 4 | sur
# Processing Record 29 of Set 4 | mehamn
# Processing Record 30 of Set 4 | trapani
# Processing Record 31 of Set 4 | paciran
# Processing Record 32 of Set 4 | sorvag
# Data unavilable...skipping.
# Processing Record 33 of Set 4 | tura
# Processing Record 34 of Set 4 | seminole
# Processing Record 35 of Set 4 | makriyialos
# Data unavilable...skipping.
# Processing Record 36 of Set 4 | bud
# Processing Record 37 of Set 4 | bolonchen
# Data unavilable...skipping.
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | pedro carbo
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | noumea
# Processing Record 46 of Set 4 | kamenka
# Processing Record 47 of Set 4 | poum
# Processing Record 48 of Set 4 | tingi
# Processing Record 49 of Set 4 | hamilton
# Processing Record 0 of Set 5 | lahaina
# Processing Record 1 of Set 5 | high level
# Processing Record 2 of Set 5 | mackay
# Processing Record 3 of Set 5 | novosheshminsk
# Processing Record 4 of Set 5 | port keats
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | hirara
# Processing Record 7 of Set 5 | araouane
# Processing Record 8 of Set 5 | poso
# Processing Record 9 of Set 5 | louisbourg
# Data unavilable...skipping.
# Processing Record 10 of Set 5 | grafton
# Processing Record 11 of Set 5 | melfort
# Processing Record 12 of Set 5 | hammerfest
# Processing Record 13 of Set 5 | aporawan
# Data unavilable...skipping.
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | bengkulu
# Data unavilable...skipping.
# Processing Record 16 of Set 5 | rorvik
# Processing Record 17 of Set 5 | mattawa
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | dikson
# Processing Record 20 of Set 5 | challapata
# Processing Record 21 of Set 5 | pontianak
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | te anau
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | lanxi
# Processing Record 26 of Set 5 | jiexiu
# Processing Record 27 of Set 5 | stokmarknes
# Processing Record 28 of Set 5 | havre
# Processing Record 29 of Set 5 | krasnokholmskiy
# Processing Record 30 of Set 5 | marang
# Data unavilable...skipping.
# Processing Record 31 of Set 5 | gayeri
# Processing Record 32 of Set 5 | sembe
# Data unavilable...skipping.
# Processing Record 33 of Set 5 | griffith
# Processing Record 34 of Set 5 | sao miguel do araguaia
# Processing Record 35 of Set 5 | fallon
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | yerbogachen
# Processing Record 39 of Set 5 | oga
# Processing Record 40 of Set 5 | san jeronimo
# Processing Record 41 of Set 5 | ogembo
# Processing Record 42 of Set 5 | samalaeulu
# Data unavilable...skipping.
# Processing Record 43 of Set 5 | tabou
# Processing Record 44 of Set 5 | lima
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | shieli
# Processing Record 47 of Set 5 | phangnga
# Processing Record 48 of Set 5 | copperas cove
# Processing Record 49 of Set 5 | uchiza
# Processing Record 0 of Set 6 | cheuskiny
# Data unavilable...skipping.
# Processing Record 1 of Set 6 | mnogovershinnyy
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | marathon
# Processing Record 4 of Set 6 | lazarev
# Processing Record 5 of Set 6 | sorong
# Processing Record 6 of Set 6 | mazamari
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | bethel
# Processing Record 9 of Set 6 | gao
# Processing Record 10 of Set 6 | marshfield
# Processing Record 11 of Set 6 | wanning
# Processing Record 12 of Set 6 | mosquera
# Processing Record 13 of Set 6 | koumac
# Processing Record 14 of Set 6 | anloga
# Processing Record 15 of Set 6 | marawi
# Processing Record 16 of Set 6 | livingstonia
# Processing Record 17 of Set 6 | skibbereen
# Processing Record 18 of Set 6 | deputatskiy
# Processing Record 19 of Set 6 | north bend
# Processing Record 20 of Set 6 | russell
# Processing Record 21 of Set 6 | dongying
# Processing Record 22 of Set 6 | faya
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | batagay
# Processing Record 25 of Set 6 | skalistyy
# Data unavilable...skipping.
# Processing Record 26 of Set 6 | tateyama
# Processing Record 27 of Set 6 | richards bay
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | nanakuli
# Processing Record 30 of Set 6 | madukkur
# Processing Record 31 of Set 6 | guane
# Processing Record 32 of Set 6 | ilulissat
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | yurga
# Processing Record 35 of Set 6 | tubmanburg
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | henties bay
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | ahipara
# Processing Record 40 of Set 6 | kaduqli
# Processing Record 41 of Set 6 | mbigou
# Processing Record 42 of Set 6 | jaumave
# Processing Record 43 of Set 6 | palmer
# Processing Record 44 of Set 6 | tynda
# Processing Record 45 of Set 6 | rawannawi
# Data unavilable...skipping.
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | hasaki
# Processing Record 48 of Set 6 | larsnes
# Processing Record 49 of Set 6 | mandalgovi
# Processing Record 0 of Set 7 | caravelas
# Processing Record 1 of Set 7 | codrington
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | naryan-mar
# Processing Record 4 of Set 7 | coquimbo
# Processing Record 5 of Set 7 | mutoko
# Processing Record 6 of Set 7 | ereymentau
# Processing Record 7 of Set 7 | korla
# Data unavilable...skipping.
# Processing Record 8 of Set 7 | lugazi
# Processing Record 9 of Set 7 | broome
# Processing Record 10 of Set 7 | ostrovnoy
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | azacualpa
# Processing Record 13 of Set 7 | ciechocinek
# Processing Record 14 of Set 7 | liberal
# Processing Record 15 of Set 7 | nishihara
# Processing Record 16 of Set 7 | sao filipe
# Processing Record 17 of Set 7 | salinas
# Processing Record 18 of Set 7 | bayan
# Processing Record 19 of Set 7 | dargaville
# Processing Record 20 of Set 7 | nanortalik
# Processing Record 21 of Set 7 | ponta do sol
# Processing Record 22 of Set 7 | turquel
# Processing Record 23 of Set 7 | lawrenceburg
# Processing Record 24 of Set 7 | constitucion
# Processing Record 25 of Set 7 | san policarpo
# Processing Record 26 of Set 7 | coihaique
# Processing Record 27 of Set 7 | baghdad
# Processing Record 28 of Set 7 | isangel
# Processing Record 29 of Set 7 | grevesmuhlen
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | hami
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | kamaishi
# Processing Record 34 of Set 7 | gigmoto
# Processing Record 35 of Set 7 | taksimo
# Processing Record 36 of Set 7 | bubaque
# Processing Record 37 of Set 7 | hernani
# Processing Record 38 of Set 7 | fez
# Processing Record 39 of Set 7 | kununurra
# Processing Record 40 of Set 7 | paso de patria
# Processing Record 41 of Set 7 | moranbah
# Processing Record 42 of Set 7 | chincha alta
# Processing Record 43 of Set 7 | bandarbeyla
# Processing Record 44 of Set 7 | altamira
# Processing Record 45 of Set 7 | zhanatas
# Data unavilable...skipping.
# Processing Record 46 of Set 7 | sosua
# Processing Record 47 of Set 7 | shaunavon
# Processing Record 48 of Set 7 | cholet
# Processing Record 49 of Set 7 | seoul
# Processing Record 0 of Set 8 | leirvik
# Processing Record 1 of Set 8 | puerto escondido
# Processing Record 2 of Set 8 | kattivakkam
# Processing Record 3 of Set 8 | achisay
# Data unavilable...skipping.
# Processing Record 4 of Set 8 | nyimba
# Processing Record 5 of Set 8 | cooma
# Processing Record 6 of Set 8 | mangan
# Processing Record 7 of Set 8 | batagay-alyta
# Processing Record 8 of Set 8 | shingu
# Processing Record 9 of Set 8 | cherlak
# Processing Record 10 of Set 8 | yar-sale
# Processing Record 11 of Set 8 | posse
# Processing Record 12 of Set 8 | borlange
# Data unavilable...skipping.
# Processing Record 13 of Set 8 | price
# Processing Record 14 of Set 8 | axim
# Processing Record 15 of Set 8 | changji
# Processing Record 16 of Set 8 | las palmas
# Processing Record 17 of Set 8 | point pedro
# Processing Record 18 of Set 8 | litoral del san juan
# Data unavilable...skipping.
# Processing Record 19 of Set 8 | bukachacha
# Processing Record 20 of Set 8 | bambous virieux
# Processing Record 21 of Set 8 | aklavik
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | sistranda
# Processing Record 24 of Set 8 | abhar
# Processing Record 25 of Set 8 | nan
# Processing Record 26 of Set 8 | kabanjahe
# Processing Record 27 of Set 8 | kilmez
# Data unavilable...skipping.
# Processing Record 28 of Set 8 | cabo san lucas
# Processing Record 29 of Set 8 | pitimbu
# Processing Record 30 of Set 8 | rathdrum
# Processing Record 31 of Set 8 | maniitsoq
# Processing Record 32 of Set 8 | chipinge
# Processing Record 33 of Set 8 | vzmorye
# Data unavilable...skipping.
# Processing Record 34 of Set 8 | londiani
# Processing Record 35 of Set 8 | butterworth
# Processing Record 36 of Set 8 | vanimo
# Processing Record 37 of Set 8 | tetiz
# Processing Record 38 of Set 8 | heze
# Processing Record 39 of Set 8 | sioux lookout
# Processing Record 40 of Set 8 | kharp
# Processing Record 41 of Set 8 | ruwi
# Processing Record 42 of Set 8 | blanes
# Processing Record 43 of Set 8 | port alfred
# Processing Record 44 of Set 8 | takoradi
# Processing Record 45 of Set 8 | attawapiskat
# Data unavilable...skipping.
# Processing Record 46 of Set 8 | esna
# Processing Record 47 of Set 8 | suzhou
# Processing Record 48 of Set 8 | sri aman
# Processing Record 49 of Set 8 | boyolangu
# Processing Record 0 of Set 9 | nome
# Processing Record 1 of Set 9 | broken hill
# Processing Record 2 of Set 9 | markala
# Processing Record 3 of Set 9 | chebenki
# Processing Record 4 of Set 9 | finschhafen
# Processing Record 5 of Set 9 | port hardy
# Processing Record 6 of Set 9 | baherden
# Processing Record 7 of Set 9 | kopargaon
# Processing Record 8 of Set 9 | oksfjord
# Processing Record 9 of Set 9 | caldwell
# Processing Record 10 of Set 9 | dicabisagan
# Processing Record 11 of Set 9 | shirvan
# Data unavilable...skipping.
# Processing Record 12 of Set 9 | nicoya
# Processing Record 13 of Set 9 | sulangan
# Processing Record 14 of Set 9 | ithaca
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | burica
# Data unavilable...skipping.
# Processing Record 17 of Set 9 | buchanan
# Processing Record 18 of Set 9 | paraiso
# Processing Record 19 of Set 9 | kerema
# Processing Record 20 of Set 9 | tobermory
# Processing Record 21 of Set 9 | sabinas
# Processing Record 22 of Set 9 | warqla
# Data unavilable...skipping.
# Processing Record 23 of Set 9 | mago
# Processing Record 24 of Set 9 | yulara
# Processing Record 25 of Set 9 | saleaula
# Data unavilable...skipping.
# Processing Record 26 of Set 9 | mackenzie
# Processing Record 27 of Set 9 | wajima
# Processing Record 28 of Set 9 | zhangjiakou
# Processing Record 29 of Set 9 | izhma
# Processing Record 30 of Set 9 | itoman
# Processing Record 31 of Set 9 | jiangkou
# Processing Record 32 of Set 9 | kikwit
# Processing Record 33 of Set 9 | gat
# Processing Record 34 of Set 9 | san andres
# Processing Record 35 of Set 9 | peddapalli
# Processing Record 36 of Set 9 | saint anthony
# Processing Record 37 of Set 9 | khonuu
# Data unavilable...skipping.
# Processing Record 38 of Set 9 | khash
# Processing Record 39 of Set 9 | lompoc
# Processing Record 40 of Set 9 | vidim
# Processing Record 41 of Set 9 | migori
# Processing Record 42 of Set 9 | douglas
# Processing Record 43 of Set 9 | bogalusa
# Processing Record 44 of Set 9 | puro
# Processing Record 45 of Set 9 | brae
# Processing Record 46 of Set 9 | carutapera
# Processing Record 47 of Set 9 | grand river south east
# Data unavilable...skipping.
# Processing Record 48 of Set 9 | novikovo
# Processing Record 49 of Set 9 | lakatoro
# Processing Record 0 of Set 10 | mahajanga
# Processing Record 1 of Set 10 | rio grande
# Processing Record 2 of Set 10 | mandan
# Processing Record 3 of Set 10 | la union
# Processing Record 4 of Set 10 | guozhen
# Processing Record 5 of Set 10 | juruti
# Processing Record 6 of Set 10 | koboko
# Processing Record 7 of Set 10 | turayf
# Processing Record 8 of Set 10 | samusu
# Data unavilable...skipping.
# Processing Record 9 of Set 10 | kurilsk
# Processing Record 10 of Set 10 | mopti
# Processing Record 11 of Set 10 | krasnoselkup
# Data unavilable...skipping.
# Processing Record 12 of Set 10 | kadirli
# Processing Record 13 of Set 10 | denizli
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | superior
# Processing Record 16 of Set 10 | korce
# Processing Record 17 of Set 10 | dwarka
# Processing Record 18 of Set 10 | muros
# Processing Record 19 of Set 10 | aswan
# Processing Record 20 of Set 10 | waingapu
# Processing Record 21 of Set 10 | provideniya
# Processing Record 22 of Set 10 | skagastrond
# Data unavilable...skipping.
# Processing Record 23 of Set 10 | mungaa
# Processing Record 24 of Set 10 | menongue
# Processing Record 25 of Set 10 | bhalwal
# Processing Record 26 of Set 10 | kupang
# Processing Record 27 of Set 10 | lashio
# Processing Record 28 of Set 10 | victor harbor
# Processing Record 29 of Set 10 | tidore
# Data unavilable...skipping.
# Processing Record 30 of Set 10 | zyryanka
# Processing Record 31 of Set 10 | cuiaba
# Processing Record 32 of Set 10 | humboldt
# Processing Record 33 of Set 10 | teya
# Processing Record 34 of Set 10 | urucara
# Processing Record 35 of Set 10 | zhigansk
# Processing Record 36 of Set 10 | angoche
# Processing Record 37 of Set 10 | dubbo
# Processing Record 38 of Set 10 | jumla
# Processing Record 39 of Set 10 | aitape
# Processing Record 40 of Set 10 | evensk
# Processing Record 41 of Set 10 | namatanai
# Processing Record 42 of Set 10 | fuxin
# Processing Record 43 of Set 10 | chake chake
# Processing Record 44 of Set 10 | morro bay
# Processing Record 45 of Set 10 | rizhao
# Processing Record 46 of Set 10 | brookhaven
# Processing Record 47 of Set 10 | aksu
# Processing Record 48 of Set 10 | haines junction
# Processing Record 49 of Set 10 | pacific grove
# Processing Record 0 of Set 11 | kabin buri
# Processing Record 1 of Set 11 | gustavo diaz ordaz
# Processing Record 2 of Set 11 | padang
# Processing Record 3 of Set 11 | umm lajj
# Processing Record 4 of Set 11 | muravlenko
# Processing Record 5 of Set 11 | chernyshevskiy
# Processing Record 6 of Set 11 | lodingen
# Processing Record 7 of Set 11 | notodden
# Processing Record 8 of Set 11 | erechim
# Processing Record 9 of Set 11 | waspan
# Data unavilable...skipping.
# Processing Record 10 of Set 11 | nurmijarvi
# Processing Record 11 of Set 11 | puerto madero
# Processing Record 12 of Set 11 | karasjok
# Processing Record 13 of Set 11 | airai
# Processing Record 14 of Set 11 | ijui
# Processing Record 15 of Set 11 | port blair
# Processing Record 16 of Set 11 | lagoa
# Processing Record 17 of Set 11 | girne
# Data unavilable...skipping.
# Processing Record 18 of Set 11 | cap malheureux
# Processing Record 19 of Set 11 | sanghar
# Processing Record 20 of Set 11 | turukhansk
# Processing Record 21 of Set 11 | lolua
# Data unavilable...skipping.
# Processing Record 22 of Set 11 | oktyabrskiy
# Processing Record 23 of Set 11 | kirakira
# Processing Record 24 of Set 11 | mabaruma
# Processing Record 25 of Set 11 | banda aceh
# Processing Record 26 of Set 11 | bandar-e lengeh
# Processing Record 27 of Set 11 | berdigestyakh
# Processing Record 28 of Set 11 | sao joao da barra
# Processing Record 29 of Set 11 | praia da vitoria
# Processing Record 30 of Set 11 | yanchukan
# Data unavilable...skipping.
# Processing Record 31 of Set 11 | usinsk
# Processing Record 32 of Set 11 | kadykchan
# Data unavilable...skipping.
# Processing Record 33 of Set 11 | nurota
# Processing Record 34 of Set 11 | gamba
# Processing Record 35 of Set 11 | tanshui
# Data unavilable...skipping.
# Processing Record 36 of Set 11 | la paz
# Processing Record 37 of Set 11 | kalas
# Processing Record 38 of Set 11 | syracuse
# Processing Record 39 of Set 11 | abonnema
# Processing Record 40 of Set 11 | flinders
# Processing Record 41 of Set 11 | genhe
# Processing Record 42 of Set 11 | torbay
# Processing Record 43 of Set 11 | ponta delgada
# Processing Record 44 of Set 11 | kurkino
# Processing Record 45 of Set 11 | puerto palomas
# Processing Record 46 of Set 11 | liverpool
# Processing Record 47 of Set 11 | ijaki
# Data unavilable...skipping.
# Processing Record 48 of Set 11 | ramos arizpe
# Processing Record 49 of Set 11 | homer
# Processing Record 0 of Set 12 | keti bandar
# Processing Record 1 of Set 12 | benjamin aceval
# Processing Record 2 of Set 12 | magistralnyy
# Processing Record 3 of Set 12 | atambua
# Processing Record 4 of Set 12 | quelimane
# Processing Record 5 of Set 12 | predivinsk
# Processing Record 6 of Set 12 | aktash
# Data unavilable...skipping.
# Processing Record 7 of Set 12 | veraval
# Processing Record 8 of Set 12 | khandbari
# Processing Record 9 of Set 12 | magole
# Processing Record 10 of Set 12 | raudeberg
# Processing Record 11 of Set 12 | abu dhabi
# Processing Record 12 of Set 12 | nizhneyansk
# Data unavilable...skipping.
# Processing Record 13 of Set 12 | haverfordwest
# Processing Record 14 of Set 12 | sabang
# Processing Record 15 of Set 12 | maarianhamina
# Data unavilable...skipping.
# Processing Record 16 of Set 12 | uvalde
# Processing Record 17 of Set 12 | perth
# Processing Record 18 of Set 12 | banikoara
# Processing Record 19 of Set 12 | fort-shevchenko
# Processing Record 20 of Set 12 | najran
# Processing Record 21 of Set 12 | dali
# Processing Record 22 of Set 12 | smithers
# Processing Record 23 of Set 12 | lakes entrance
# Processing Record 24 of Set 12 | okhotsk
# Processing Record 25 of Set 12 | lebedinyy
# Processing Record 26 of Set 12 | kaeo
# Processing Record 27 of Set 12 | kaseda
# Processing Record 28 of Set 12 | lengshuitan
# Processing Record 29 of Set 12 | camana
# Data unavilable...skipping.
# Processing Record 30 of Set 12 | arman
# Processing Record 31 of Set 12 | huangchuan
# Processing Record 32 of Set 12 | san jose
# Processing Record 33 of Set 12 | banjar
# Processing Record 34 of Set 12 | highland
# Processing Record 35 of Set 12 | fort nelson
# Processing Record 36 of Set 12 | san martin
# Processing Record 37 of Set 12 | namibe
# Processing Record 38 of Set 12 | hovd
# Processing Record 39 of Set 12 | grande prairie
# Processing Record 40 of Set 12 | liebling
# Processing Record 41 of Set 12 | kemijarvi
# Data unavilable...skipping.
# Processing Record 42 of Set 12 | korhogo
# Processing Record 43 of Set 12 | bogashevo
# Processing Record 44 of Set 12 | fortuna
# Processing Record 45 of Set 12 | dolores
# Processing Record 46 of Set 12 | okha
# Processing Record 47 of Set 12 | euclides da cunha
# Processing Record 48 of Set 12 | kyra
# Data unavilable...skipping.
# Processing Record 49 of Set 12 | great yarmouth
# Processing Record 0 of Set 13 | makaha
# Processing Record 1 of Set 13 | ramasukha
# Data unavilable...skipping.
# Processing Record 2 of Set 13 | dingle
# Processing Record 3 of Set 13 | port hedland
# Processing Record 4 of Set 13 | isabela
# Processing Record 5 of Set 13 | pionerskiy
# Processing Record 6 of Set 13 | milkovo
# Processing Record 7 of Set 13 | college
# Processing Record 8 of Set 13 | xining
# Processing Record 9 of Set 13 | puerto del rosario
# Processing Record 10 of Set 13 | ashland
# Processing Record 11 of Set 13 | xichang
# Processing Record 12 of Set 13 | mocambique
# Data unavilable...skipping.
# Processing Record 13 of Set 13 | alyangula
# Processing Record 14 of Set 13 | front royal
# Processing Record 15 of Set 13 | saint-georges
# Processing Record 16 of Set 13 | ranong
# Processing Record 17 of Set 13 | barra do corda
# Processing Record 18 of Set 13 | buala
# Processing Record 19 of Set 13 | eirunepe
# Processing Record 20 of Set 13 | puerto narino
# Processing Record 21 of Set 13 | katangli
# Processing Record 22 of Set 13 | plouzane
# Processing Record 23 of Set 13 | yigou
# Processing Record 24 of Set 13 | japura
# Processing Record 25 of Set 13 | black river
# Processing Record 26 of Set 13 | svetlogorsk
# Processing Record 27 of Set 13 | le port
# Processing Record 28 of Set 13 | vardo
# Processing Record 29 of Set 13 | umzimvubu
# Data unavilable...skipping.
# Processing Record 30 of Set 13 | ternate
# Processing Record 31 of Set 13 | killybegs

# %% [markdown]
# ### Verify count of each variable is consistent for dataset and reaches 500 city minimum

# %%
print(f"Cities count {len(cities)}")

print(f"Countries count {len(countries)}")

print(f"Date count {len(dates)}")

print(f"Lat count {len(lat)}")

print(f"Lon count {len(lon)}")

print(f"Max Temp count {len(temp_max)}")

print(f"Humidity count {len(humidity)}")

print(f"Clouds count {len(clouds)}")

print(f"Wind_speed count {len(wind_speed)}")
# Out:
# Cities count 567
# Countries count 567
# Date count 567
# Lat count 567
# Lon count 567
# Max Temp count 567
# Humidity count 567
# Clouds count 567
# Wind_speed count 567

# %% [markdown]
# ### Create a dictonary with variables above

# %%
weather_dict = {
    
    "City": cities,
    
    "Country": countries,
    
    "Date": dates,
    
    "Lat": lat,
    
    "Lon":lon,
    
    "Max Temp": temp_max,
    
    "Humidity": humidity,
    
    "Cloudiness": clouds,
    
    "Wind Speed": wind_speed
}

# %% [markdown]
# ### Create new dataframe using weather dictonary created above

# %%
weather_data = pd.DataFrame(weather_dict)

# %% [markdown]
# ### Output File (CSV)

# %%
output_data_file = "../Resources/citiesWeather.csv"

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv(output_data_file, encoding='utf-8', index=True,sep=',',header=True, na_rep='NaN')

weather_data.head()
# Out:
#              City Country        Date    Lat     Lon  Max Temp  Humidity  \
# 0     New Norfolk      AU  1540587600 -42.78  147.06     55.40        50
# 1         Hualmay      PE  1540589363 -11.10  -77.61     70.02        65
# 2           Ejura      GH  1540589363   7.38   -1.37     74.07        92
# 3          Zhuhai      CN  1540584000  40.71  112.04     21.20        67
# 4  Vestmannaeyjar      IS  1540589364  63.44  -20.27     30.19       100
#
#    Cloudiness  Wind Speed
# 0          75        9.17
# 1          24        6.78
# 2          56        2.53
# 3           0        2.24
# 4           0       15.73

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", alpha =.7, edgecolors='black')

# Incorporate the other graph properties

plt.title("City Latitude vs Max Temperature (10/21/2018) ")

plt.ylabel("Max Temperature (F)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsTemp.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", alpha =.7, edgecolors='black')

# Incorporate the other graph properties

plt.title("City Latitude vs Humidity(10/21/2018) ")

plt.ylabel("Humidity(%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsHumidity.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", alpha =.7, edgecolors='black')

# Incorporate the other graph properties

plt.title("City Latitude vsCloudiness(10/21/2018) ")

plt.ylabel("Cloudiness(%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsCloudiness.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", alpha =.7, edgecolors='black')

# Incorporate the other graph properties

plt.title("City Latitude vs Wind Speed(10/21/2018) ")

plt.ylabel("Wind Speed (mph)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsWindSpeed.png")

# Show plot

plt.show()

# %% [markdown]
# ### Conclusion
# * The weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude).
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

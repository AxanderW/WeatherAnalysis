# %% [markdown]
# ### Dependencies and Setup

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import requests

import time

from pprint import pprint

import openweathermapy.core as owm

from api_keys import api_key

from citipy import citipy

from datetime import datetime

# %% [markdown]
# ### Set Range of latitudes and longitudes

# %%
lat_range = (-90, 90)

lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []

cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:

    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 623

# %% [markdown]
# ### Create an empty dataframe with cities column to store weather variables

# %%
cities_data = pd.DataFrame(cities)

cities_data = cities_data.rename(columns={0: "City"})

cities_data["Temperature"] = ""

cities_data["Lat"] = ""

cities_data["Lon"] = ""

cities_data["Humidity"] = ""

cities_data["Cloudiness"] = ""

cities_data["Wind Speed"] = ""


cities_data.head()
# Out:
#              City Temperature Lat Lon Humidity Cloudiness Wind Speed
# 0  saint-augustin
# 1     mys shmidta
# 2          albany
# 3           bluff
# 4         isangel

# %% [markdown]
# ### Build URL inputs for API Calls

# %%
units = "imperial"

base_url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{base_url}appid={api_key}&units={units}&q="

# %% [markdown]
# ### Create empty list for each weather variable

# %%
lat = []

lon = []

temp_max = []

humidity = []

clouds = []

wind_speed = []

cities = []

dates = []

countries = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
record_count = 1

set_count = 1

for index, row in cities_data.iterrows():

    if (index % 50 == 0 and index >= 50):

        set_count += 1

        record_count = 0

    city = row["City"]

    final_query_url = query_url+city

    print("Processing Record %s of Set %s | %s" %
          (record_count, set_count, city))

    record_count += 1

    response = requests.get(final_query_url).json()

    try:

        cities.append(response['name'])

        dates.append(response['dt'])

        countries.append(response['sys']['country'])

        lon.append(response['coord']['lon'])

        lat.append(response['coord']['lat'])

        temp_max.append(response['main']['temp_max'])

        humidity.append(response['main']['humidity'])

        clouds.append(response['clouds']['all'])

        wind_speed.append(response['wind']['speed'])

    except (KeyError):

        print("Data unavilable...skipping.")
# Out:
# Processing Record 1 of Set 1 | saint-augustin
# Processing Record 2 of Set 1 | mys shmidta
# Data unavilable...skipping.
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | isangel
# Processing Record 6 of Set 1 | korla
# Data unavilable...skipping.
# Processing Record 7 of Set 1 | kosa
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | harlingen
# Processing Record 10 of Set 1 | kupang
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | fenoarivo atsinanana
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | chivay
# Processing Record 21 of Set 1 | eniwa
# Processing Record 22 of Set 1 | barentsburg
# Data unavilable...skipping.
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | kuche
# Data unavilable...skipping.
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | mehamn
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | lavrentiya
# Processing Record 31 of Set 1 | cagayan de tawi-tawi
# Data unavilable...skipping.
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | dunedin
# Processing Record 34 of Set 1 | buariki
# Data unavilable...skipping.
# Processing Record 35 of Set 1 | college
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | nalut
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | labuan
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | shulan
# Processing Record 47 of Set 1 | boa vista
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 0 of Set 2 | port hardy
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | tual
# Processing Record 3 of Set 2 | jaisalmer
# Processing Record 4 of Set 2 | saint-francois
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | omboue
# Processing Record 9 of Set 2 | tilichiki
# Processing Record 10 of Set 2 | bonavista
# Processing Record 11 of Set 2 | half moon bay
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | mariental
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | jalu
# Processing Record 17 of Set 2 | kavaratti
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | port augusta
# Processing Record 20 of Set 2 | juneau
# Processing Record 21 of Set 2 | palabuhanratu
# Data unavilable...skipping.
# Processing Record 22 of Set 2 | kiama
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | buala
# Processing Record 25 of Set 2 | blackwater
# Processing Record 26 of Set 2 | aykino
# Processing Record 27 of Set 2 | lerwick
# Processing Record 28 of Set 2 | attawapiskat
# Data unavilable...skipping.
# Processing Record 29 of Set 2 | zhigansk
# Processing Record 30 of Set 2 | malwan
# Data unavilable...skipping.
# Processing Record 31 of Set 2 | torbay
# Processing Record 32 of Set 2 | buluang
# Processing Record 33 of Set 2 | tolaga bay
# Processing Record 34 of Set 2 | daudnagar
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | hami
# Processing Record 37 of Set 2 | yumen
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | karamea
# Data unavilable...skipping.
# Processing Record 40 of Set 2 | tabiauea
# Data unavilable...skipping.
# Processing Record 41 of Set 2 | rafaela
# Processing Record 42 of Set 2 | letlhakane
# Processing Record 43 of Set 2 | nizhneyansk
# Data unavilable...skipping.
# Processing Record 44 of Set 2 | kalyazin
# Processing Record 45 of Set 2 | naze
# Processing Record 46 of Set 2 | henties bay
# Processing Record 47 of Set 2 | labuhan
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | wattegama
# Processing Record 0 of Set 3 | stornoway
# Data unavilable...skipping.
# Processing Record 1 of Set 3 | jining
# Processing Record 2 of Set 3 | caravelas
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | xiuyan
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | olinda
# Processing Record 8 of Set 3 | carmen
# Processing Record 9 of Set 3 | portland
# Processing Record 10 of Set 3 | sawakin
# Processing Record 11 of Set 3 | rypin
# Processing Record 12 of Set 3 | rocha
# Processing Record 13 of Set 3 | quatre cocos
# Processing Record 14 of Set 3 | severo-kurilsk
# Processing Record 15 of Set 3 | meulaboh
# Processing Record 16 of Set 3 | zhanaozen
# Processing Record 17 of Set 3 | shulin
# Processing Record 18 of Set 3 | viedma
# Processing Record 19 of Set 3 | matara
# Processing Record 20 of Set 3 | polovinnoye
# Processing Record 21 of Set 3 | zhangye
# Processing Record 22 of Set 3 | manokwari
# Processing Record 23 of Set 3 | sumbawa
# Data unavilable...skipping.
# Processing Record 24 of Set 3 | martapura
# Processing Record 25 of Set 3 | vestmannaeyjar
# Processing Record 26 of Set 3 | mayumba
# Processing Record 27 of Set 3 | madikeri
# Processing Record 28 of Set 3 | salinas
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | palapye
# Processing Record 31 of Set 3 | tsihombe
# Data unavilable...skipping.
# Processing Record 32 of Set 3 | kiruna
# Processing Record 33 of Set 3 | ust-kulom
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | kalmunai
# Processing Record 39 of Set 3 | vostok
# Processing Record 40 of Set 3 | marsa matruh
# Processing Record 41 of Set 3 | bezerros
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | taolanaro
# Data unavilable...skipping.
# Processing Record 44 of Set 3 | bethanien
# Processing Record 45 of Set 3 | tukums
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | bose
# Processing Record 48 of Set 3 | huilong
# Processing Record 49 of Set 3 | airai
# Processing Record 0 of Set 4 | bethel
# Processing Record 1 of Set 4 | sentyabrskiy
# Data unavilable...skipping.
# Processing Record 2 of Set 4 | macusani
# Processing Record 3 of Set 4 | taos
# Processing Record 4 of Set 4 | pak thong chai
# Processing Record 5 of Set 4 | tucurui
# Processing Record 6 of Set 4 | sokolka
# Processing Record 7 of Set 4 | nome
# Processing Record 8 of Set 4 | mananara
# Data unavilable...skipping.
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | vaitupu
# Data unavilable...skipping.
# Processing Record 11 of Set 4 | key largo
# Processing Record 12 of Set 4 | la asuncion
# Processing Record 13 of Set 4 | delmiro gouveia
# Processing Record 14 of Set 4 | mogadishu
# Processing Record 15 of Set 4 | siteki
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | weirton
# Processing Record 18 of Set 4 | tecpan
# Processing Record 19 of Set 4 | lilongwe
# Processing Record 20 of Set 4 | illoqqortoormiut
# Data unavilable...skipping.
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | narsaq
# Processing Record 23 of Set 4 | aksu
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | arlit
# Processing Record 26 of Set 4 | karaton
# Processing Record 27 of Set 4 | pilar
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | port lincoln
# Processing Record 30 of Set 4 | okhotsk
# Processing Record 31 of Set 4 | tasiilaq
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | komsomolskiy
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | chokurdakh
# Processing Record 36 of Set 4 | prince rupert
# Processing Record 37 of Set 4 | methoni
# Processing Record 38 of Set 4 | luanda
# Processing Record 39 of Set 4 | zigong
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | bugyi
# Processing Record 42 of Set 4 | laupheim
# Processing Record 43 of Set 4 | gisborne
# Processing Record 44 of Set 4 | victoria
# Processing Record 45 of Set 4 | komyshnya
# Data unavilable...skipping.
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | hilo
# Processing Record 48 of Set 4 | bur gabo
# Data unavilable...skipping.
# Processing Record 49 of Set 4 | san ignacio
# Processing Record 0 of Set 5 | fairbanks
# Processing Record 1 of Set 5 | tumannyy
# Data unavilable...skipping.
# Processing Record 2 of Set 5 | anastacio
# Processing Record 3 of Set 5 | mayo
# Processing Record 4 of Set 5 | gambela
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | kiunga
# Processing Record 7 of Set 5 | lodja
# Processing Record 8 of Set 5 | peniche
# Processing Record 9 of Set 5 | lolua
# Data unavilable...skipping.
# Processing Record 10 of Set 5 | tiksi
# Processing Record 11 of Set 5 | agha jari
# Data unavilable...skipping.
# Processing Record 12 of Set 5 | balkhash
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | avarua
# Processing Record 15 of Set 5 | kathu
# Processing Record 16 of Set 5 | ahtopol
# Processing Record 17 of Set 5 | kletskaya
# Processing Record 18 of Set 5 | vanavara
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | santiago de cao
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | kaihua
# Processing Record 24 of Set 5 | maceio
# Processing Record 25 of Set 5 | mishkino
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | grand river south east
# Data unavilable...skipping.
# Processing Record 28 of Set 5 | galgani
# Data unavilable...skipping.
# Processing Record 29 of Set 5 | selikhino
# Processing Record 30 of Set 5 | kampene
# Processing Record 31 of Set 5 | tommot
# Processing Record 32 of Set 5 | paradwip
# Data unavilable...skipping.
# Processing Record 33 of Set 5 | marcona
# Data unavilable...skipping.
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | los llanos de aridane
# Processing Record 36 of Set 5 | gelibolu
# Processing Record 37 of Set 5 | lagoa
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | katherine
# Processing Record 40 of Set 5 | beringovskiy
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | avanigadda
# Processing Record 43 of Set 5 | port shepstone
# Processing Record 44 of Set 5 | nanortalik
# Processing Record 45 of Set 5 | coahuayana
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | saldanha
# Processing Record 48 of Set 5 | sesimbra
# Processing Record 49 of Set 5 | voh
# Processing Record 0 of Set 6 | kahului
# Processing Record 1 of Set 6 | kindu
# Processing Record 2 of Set 6 | zhangzhou
# Processing Record 3 of Set 6 | tautira
# Processing Record 4 of Set 6 | ucluelet
# Processing Record 5 of Set 6 | ponta do sol
# Processing Record 6 of Set 6 | victor harbor
# Processing Record 7 of Set 6 | neiafu
# Processing Record 8 of Set 6 | zhumadian
# Processing Record 9 of Set 6 | laguna
# Processing Record 10 of Set 6 | bengkulu
# Data unavilable...skipping.
# Processing Record 11 of Set 6 | kemin
# Processing Record 12 of Set 6 | sun valley
# Processing Record 13 of Set 6 | churapcha
# Processing Record 14 of Set 6 | amantea
# Processing Record 15 of Set 6 | inuvik
# Processing Record 16 of Set 6 | amderma
# Data unavilable...skipping.
# Processing Record 17 of Set 6 | minanga
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | belushya guba
# Data unavilable...skipping.
# Processing Record 20 of Set 6 | idlib
# Processing Record 21 of Set 6 | acapulco
# Processing Record 22 of Set 6 | menongue
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | san carlos de bariloche
# Processing Record 25 of Set 6 | xining
# Processing Record 26 of Set 6 | vila velha
# Processing Record 27 of Set 6 | huaiyin
# Processing Record 28 of Set 6 | sakaiminato
# Processing Record 29 of Set 6 | liberal
# Processing Record 30 of Set 6 | coolum beach
# Processing Record 31 of Set 6 | chapais
# Processing Record 32 of Set 6 | atikokan
# Processing Record 33 of Set 6 | hualmay
# Processing Record 34 of Set 6 | telde
# Processing Record 35 of Set 6 | jatai
# Processing Record 36 of Set 6 | luderitz
# Processing Record 37 of Set 6 | kabinda
# Processing Record 38 of Set 6 | hervey bay
# Processing Record 39 of Set 6 | marzuq
# Processing Record 40 of Set 6 | saint george
# Processing Record 41 of Set 6 | krasnoselkup
# Data unavilable...skipping.
# Processing Record 42 of Set 6 | kabanjahe
# Processing Record 43 of Set 6 | kavieng
# Processing Record 44 of Set 6 | sinnamary
# Processing Record 45 of Set 6 | hastings
# Processing Record 46 of Set 6 | teya
# Processing Record 47 of Set 6 | keokuk
# Processing Record 48 of Set 6 | karakendzha
# Data unavilable...skipping.
# Processing Record 49 of Set 6 | maarianhamina
# Data unavilable...skipping.
# Processing Record 0 of Set 7 | colares
# Processing Record 1 of Set 7 | acarau
# Data unavilable...skipping.
# Processing Record 2 of Set 7 | ciudad bolivar
# Processing Record 3 of Set 7 | sakakah
# Data unavilable...skipping.
# Processing Record 4 of Set 7 | rorvik
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | shingu
# Processing Record 7 of Set 7 | asau
# Data unavilable...skipping.
# Processing Record 8 of Set 7 | el alto
# Processing Record 9 of Set 7 | talcahuano
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 7 | ziro
# Processing Record 13 of Set 7 | aksarka
# Processing Record 14 of Set 7 | port macquarie
# Processing Record 15 of Set 7 | kastamonu
# Processing Record 16 of Set 7 | yetkul
# Processing Record 17 of Set 7 | polis
# Processing Record 18 of Set 7 | senanga
# Processing Record 19 of Set 7 | zitiste
# Processing Record 20 of Set 7 | atar
# Processing Record 21 of Set 7 | lebu
# Processing Record 22 of Set 7 | soe
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | calca
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | amga
# Processing Record 27 of Set 7 | galle
# Processing Record 28 of Set 7 | ubala
# Processing Record 29 of Set 7 | tapah
# Processing Record 30 of Set 7 | junction city
# Processing Record 31 of Set 7 | yakeshi
# Processing Record 32 of Set 7 | brae
# Processing Record 33 of Set 7 | astoria
# Processing Record 34 of Set 7 | ossora
# Processing Record 35 of Set 7 | thompson
# Processing Record 36 of Set 7 | koulamoutou
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | mikhaylovka
# Processing Record 39 of Set 7 | tokur
# Processing Record 40 of Set 7 | havelock
# Processing Record 41 of Set 7 | haapiti
# Processing Record 42 of Set 7 | susanville
# Processing Record 43 of Set 7 | somerset west
# Processing Record 44 of Set 7 | kailaras
# Processing Record 45 of Set 7 | jihlava
# Processing Record 46 of Set 7 | rudnogorsk
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | oksfjord
# Processing Record 49 of Set 7 | bull savanna
# Processing Record 0 of Set 8 | florianopolis
# Processing Record 1 of Set 8 | mount gambier
# Processing Record 2 of Set 8 | sitka
# Processing Record 3 of Set 8 | kamloops
# Processing Record 4 of Set 8 | lufilufi
# Processing Record 5 of Set 8 | wulanhaote
# Data unavilable...skipping.
# Processing Record 6 of Set 8 | pedernales
# Processing Record 7 of Set 8 | port moresby
# Processing Record 8 of Set 8 | uk
# Data unavilable...skipping.
# Processing Record 9 of Set 8 | nalgonda
# Processing Record 10 of Set 8 | biak
# Processing Record 11 of Set 8 | sohagpur
# Processing Record 12 of Set 8 | drayton valley
# Processing Record 13 of Set 8 | sao jose da coroa grande
# Processing Record 14 of Set 8 | haines junction
# Processing Record 15 of Set 8 | dingle
# Processing Record 16 of Set 8 | pitimbu
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | north ogden
# Processing Record 19 of Set 8 | nemuro
# Processing Record 20 of Set 8 | fukue
# Processing Record 21 of Set 8 | aschersleben
# Processing Record 22 of Set 8 | ust-shonosha
# Processing Record 23 of Set 8 | svencionys
# Processing Record 24 of Set 8 | aksum
# Processing Record 25 of Set 8 | kazalinsk
# Data unavilable...skipping.
# Processing Record 26 of Set 8 | opuwo
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | tiznit
# Processing Record 29 of Set 8 | maragogi
# Processing Record 30 of Set 8 | bemidji
# Processing Record 31 of Set 8 | makakilo city
# Processing Record 32 of Set 8 | iranshahr
# Processing Record 33 of Set 8 | reconquista
# Processing Record 34 of Set 8 | lesozavodsk
# Processing Record 35 of Set 8 | westport
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | great bend
# Processing Record 38 of Set 8 | hovd
# Processing Record 39 of Set 8 | shar
# Processing Record 40 of Set 8 | nuuk
# Processing Record 41 of Set 8 | trelew
# Processing Record 42 of Set 8 | amuntai
# Processing Record 43 of Set 8 | santiago del estero
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | barra do garcas
# Processing Record 46 of Set 8 | alice springs
# Processing Record 47 of Set 8 | rafai
# Processing Record 48 of Set 8 | galeana
# Processing Record 49 of Set 8 | richards bay
# Processing Record 0 of Set 9 | lawton
# Processing Record 1 of Set 9 | ixtapa
# Processing Record 2 of Set 9 | zhangjiakou
# Processing Record 3 of Set 9 | rawson
# Processing Record 4 of Set 9 | karaul
# Data unavilable...skipping.
# Processing Record 5 of Set 9 | tazovskiy
# Processing Record 6 of Set 9 | krasnoarmeysk
# Processing Record 7 of Set 9 | puerto varas
# Processing Record 8 of Set 9 | thanh hoa
# Processing Record 9 of Set 9 | excelsior springs
# Processing Record 10 of Set 9 | saleaula
# Data unavilable...skipping.
# Processing Record 11 of Set 9 | dryden
# Processing Record 12 of Set 9 | kalasin
# Processing Record 13 of Set 9 | george town
# Processing Record 14 of Set 9 | armenis
# Processing Record 15 of Set 9 | mareeba
# Processing Record 16 of Set 9 | non sung
# Processing Record 17 of Set 9 | constitucion
# Processing Record 18 of Set 9 | itarema
# Processing Record 19 of Set 9 | keroka
# Processing Record 20 of Set 9 | labutta
# Data unavilable...skipping.
# Processing Record 21 of Set 9 | a
# Data unavilable...skipping.
# Processing Record 22 of Set 9 | mount isa
# Processing Record 23 of Set 9 | nishihara
# Processing Record 24 of Set 9 | nantucket
# Processing Record 25 of Set 9 | bossier city
# Processing Record 26 of Set 9 | orchard homes
# Processing Record 27 of Set 9 | biloela
# Processing Record 28 of Set 9 | gorkovskoye
# Data unavilable...skipping.
# Processing Record 29 of Set 9 | kontagora
# Processing Record 30 of Set 9 | chauk
# Processing Record 31 of Set 9 | kokopo
# Processing Record 32 of Set 9 | hamilton
# Processing Record 33 of Set 9 | athabasca
# Processing Record 34 of Set 9 | iwanai
# Processing Record 35 of Set 9 | turochak
# Processing Record 36 of Set 9 | ayios kirikos
# Data unavilable...skipping.
# Processing Record 37 of Set 9 | espinosa
# Processing Record 38 of Set 9 | hay river
# Processing Record 39 of Set 9 | voyinka
# Processing Record 40 of Set 9 | padang
# Processing Record 41 of Set 9 | wanning
# Processing Record 42 of Set 9 | parsabad
# Processing Record 43 of Set 9 | ust-tsilma
# Processing Record 44 of Set 9 | elizabeth city
# Processing Record 45 of Set 9 | payakumbuh
# Processing Record 46 of Set 9 | araouane
# Processing Record 47 of Set 9 | montrose
# Processing Record 48 of Set 9 | necochea
# Processing Record 49 of Set 9 | mahebourg
# Processing Record 0 of Set 10 | coihaique
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | tomohon
# Processing Record 3 of Set 10 | quarai
# Processing Record 4 of Set 10 | bambous virieux
# Processing Record 5 of Set 10 | wilmington
# Processing Record 6 of Set 10 | karlstad
# Processing Record 7 of Set 10 | libertador general san martin
# Processing Record 8 of Set 10 | guerrero negro
# Processing Record 9 of Set 10 | atasu
# Processing Record 10 of Set 10 | yarada
# Processing Record 11 of Set 10 | moron
# Processing Record 12 of Set 10 | dicamay
# Processing Record 13 of Set 10 | kisarawe
# Processing Record 14 of Set 10 | kalemie
# Processing Record 15 of Set 10 | sapa
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | sabang
# Processing Record 18 of Set 10 | kolyvan
# Processing Record 19 of Set 10 | salalah
# Processing Record 20 of Set 10 | kunjah
# Processing Record 21 of Set 10 | esna
# Processing Record 22 of Set 10 | tombouctou
# Processing Record 23 of Set 10 | fare
# Processing Record 24 of Set 10 | ravar
# Processing Record 25 of Set 10 | kapit
# Processing Record 26 of Set 10 | juegang
# Processing Record 27 of Set 10 | mafinga
# Data unavilable...skipping.
# Processing Record 28 of Set 10 | wajima
# Processing Record 29 of Set 10 | chokwe
# Data unavilable...skipping.
# Processing Record 30 of Set 10 | samalaeulu
# Data unavilable...skipping.
# Processing Record 31 of Set 10 | nouadhibou
# Processing Record 32 of Set 10 | fort frances
# Processing Record 33 of Set 10 | qesarya
# Processing Record 34 of Set 10 | fortuna
# Processing Record 35 of Set 10 | taiyuan
# Processing Record 36 of Set 10 | madingou
# Processing Record 37 of Set 10 | hanyang
# Processing Record 38 of Set 10 | amazar
# Processing Record 39 of Set 10 | honningsvag
# Processing Record 40 of Set 10 | charters towers
# Processing Record 41 of Set 10 | santa fe
# Processing Record 42 of Set 10 | presidencia roque saenz pena
# Processing Record 43 of Set 10 | krasnyy yar
# Processing Record 44 of Set 10 | eureka
# Processing Record 45 of Set 10 | treinta y tres
# Processing Record 46 of Set 10 | saint-georges
# Processing Record 47 of Set 10 | amurzet
# Processing Record 48 of Set 10 | lorengau
# Processing Record 49 of Set 10 | leninogorsk
# Processing Record 0 of Set 11 | burica
# Data unavilable...skipping.
# Processing Record 1 of Set 11 | healdsburg
# Processing Record 2 of Set 11 | ayios matthaios
# Data unavilable...skipping.
# Processing Record 3 of Set 11 | pyatovskiy
# Processing Record 4 of Set 11 | palmer
# Processing Record 5 of Set 11 | samusu
# Data unavilable...skipping.
# Processing Record 6 of Set 11 | poum
# Processing Record 7 of Set 11 | oreanda
# Data unavilable...skipping.
# Processing Record 8 of Set 11 | havoysund
# Processing Record 9 of Set 11 | gazli
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | oleksandrivka
# Processing Record 12 of Set 11 | sorland
# Processing Record 13 of Set 11 | argentan
# Processing Record 14 of Set 11 | olafsvik
# Data unavilable...skipping.
# Processing Record 15 of Set 11 | kashi
# Data unavilable...skipping.
# Processing Record 16 of Set 11 | malatya
# Data unavilable...skipping.
# Processing Record 17 of Set 11 | tres pontas
# Processing Record 18 of Set 11 | vestmanna
# Processing Record 19 of Set 11 | zimovniki
# Processing Record 20 of Set 11 | kawambwa
# Processing Record 21 of Set 11 | rincon de la victoria
# Processing Record 22 of Set 11 | oranjestad
# Processing Record 23 of Set 11 | salvador
# Processing Record 24 of Set 11 | orbetello
# Processing Record 25 of Set 11 | fort saint john
# Data unavilable...skipping.
# Processing Record 26 of Set 11 | murgab
# Processing Record 27 of Set 11 | raymondville
# Processing Record 28 of Set 11 | redmond
# Processing Record 29 of Set 11 | ust-kuyga
# Processing Record 30 of Set 11 | carutapera
# Processing Record 31 of Set 11 | taywarah
# Processing Record 32 of Set 11 | ituni
# Data unavilable...skipping.
# Processing Record 33 of Set 11 | soyo
# Processing Record 34 of Set 11 | kropotkin
# Processing Record 35 of Set 11 | porto walter
# Processing Record 36 of Set 11 | novaky
# Processing Record 37 of Set 11 | san mateo del mar
# Processing Record 38 of Set 11 | zwedru
# Processing Record 39 of Set 11 | saint-felicien
# Processing Record 40 of Set 11 | kargasok
# Processing Record 41 of Set 11 | baiyin
# Processing Record 42 of Set 11 | lixourion
# Processing Record 43 of Set 11 | dwarka
# Processing Record 44 of Set 11 | teknaf
# Processing Record 45 of Set 11 | miandrivazo
# Processing Record 46 of Set 11 | bilma
# Processing Record 47 of Set 11 | tromso
# Processing Record 48 of Set 11 | nyazepetrovsk
# Processing Record 49 of Set 11 | souillac
# Processing Record 0 of Set 12 | ho
# Data unavilable...skipping.
# Processing Record 1 of Set 12 | ribeira brava
# Processing Record 2 of Set 12 | belaya gora
# Processing Record 3 of Set 12 | bolshoy tsaryn
# Data unavilable...skipping.
# Processing Record 4 of Set 12 | camrose
# Processing Record 5 of Set 12 | oktyabrskiy
# Processing Record 6 of Set 12 | nanakuli
# Processing Record 7 of Set 12 | karakol
# Processing Record 8 of Set 12 | zapolyarnyy
# Processing Record 9 of Set 12 | hanmer springs
# Processing Record 10 of Set 12 | camacha
# Processing Record 11 of Set 12 | geraldton
# Processing Record 12 of Set 12 | yaan
# Processing Record 13 of Set 12 | piacabucu
# Processing Record 14 of Set 12 | bundaberg
# Processing Record 15 of Set 12 | touros
# Processing Record 16 of Set 12 | neftegorsk
# Processing Record 17 of Set 12 | kholodnyy
# Processing Record 18 of Set 12 | angoche
# Processing Record 19 of Set 12 | lincoln
# Processing Record 20 of Set 12 | progreso
# Processing Record 21 of Set 12 | awjilah
# Processing Record 22 of Set 12 | kroya
# Processing Record 23 of Set 12 | alta floresta
# Processing Record 24 of Set 12 | thinadhoo
# Processing Record 25 of Set 12 | baykit
# Processing Record 26 of Set 12 | manoharpur
# Processing Record 27 of Set 12 | matagami
# Processing Record 28 of Set 12 | christchurch
# Processing Record 29 of Set 12 | praia da vitoria
# Processing Record 30 of Set 12 | paracuru
# Processing Record 31 of Set 12 | la rioja
# Processing Record 32 of Set 12 | clonakilty
# Processing Record 33 of Set 12 | abu kamal
# Processing Record 34 of Set 12 | pacaembu
# Processing Record 35 of Set 12 | hofn
# Processing Record 36 of Set 12 | tezu
# Processing Record 37 of Set 12 | dalbandin
# Processing Record 38 of Set 12 | mocambique
# Data unavilable...skipping.
# Processing Record 39 of Set 12 | kukushtan
# Processing Record 40 of Set 12 | yichang
# Processing Record 41 of Set 12 | boatlaname
# Data unavilable...skipping.
# Processing Record 42 of Set 12 | pyapon
# Processing Record 43 of Set 12 | marmaron
# Data unavilable...skipping.
# Processing Record 44 of Set 12 | buta
# Processing Record 45 of Set 12 | chara
# Processing Record 46 of Set 12 | pirojpur
# Processing Record 47 of Set 12 | zhaotong
# Processing Record 48 of Set 12 | aden
# Processing Record 49 of Set 12 | bardiyah
# Data unavilable...skipping.
# Processing Record 0 of Set 13 | snasa
# Processing Record 1 of Set 13 | port-gentil
# Processing Record 2 of Set 13 | sergeyevka
# Processing Record 3 of Set 13 | flinders
# Processing Record 4 of Set 13 | kaura namoda
# Processing Record 5 of Set 13 | bubaque
# Processing Record 6 of Set 13 | gat
# Processing Record 7 of Set 13 | scarborough
# Processing Record 8 of Set 13 | casper
# Processing Record 9 of Set 13 | isla del bosque
# Processing Record 10 of Set 13 | adre
# Processing Record 11 of Set 13 | hanzhong
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | ambunti
# Processing Record 14 of Set 13 | asayita
# Data unavilable...skipping.
# Processing Record 15 of Set 13 | trondheim
# Processing Record 16 of Set 13 | cairns
# Processing Record 17 of Set 13 | ahipara
# Processing Record 18 of Set 13 | maldonado
# Processing Record 19 of Set 13 | hukuntsi
# Processing Record 20 of Set 13 | morondava
# Processing Record 21 of Set 13 | townsville
# Processing Record 22 of Set 13 | hongjiang

# %% [markdown]
# ### Create a dictonary with variables above

# %%
weather_dict = {

    "City": cities,

    "Country": countries,

    "Date": dates,

    "Lat": lat,

    "Lon": lon,

    "Max Temp": temp_max,

    "Humidity": humidity,

    "Cloudiness": clouds,

    "Wind Speed": wind_speed
}

# %% [markdown]
# ### Create new dataframe using weather dictonary created above

# %%
weather_data = pd.DataFrame(weather_dict)

# %% [markdown]
# ### Verify count of each variable is consistent for dataset and reaches 500 city minimum

# %%
weather_data.count()
# Out:
# City          557
# Country       557
# Date          557
# Lat           557
# Lon           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# dtype: int64

# %% [markdown]
# ### Output File (CSV)

# %%
output_data_file = "../Resources/citiesWeather.csv"

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame
# * Convert Date to m/d/y

# %%
weather_data.to_csv(output_data_file, encoding="utf-8",
                    index=True, sep=",", header=True, na_rep="NaN")

timestamp = datetime.fromtimestamp(dates[0])

actual_date = timestamp.strftime("%m/%d/%y")

weather_data.head()
# Out:
#              City Country        Date    Lat     Lon  Max Temp  Humidity  \
# 0  Saint-Augustin      FR  1540670400  44.83   -0.61     44.60        75
# 1          Albany      US  1540670040  42.65  -73.75     42.80        81
# 2           Bluff      AU  1540672535 -23.58  149.07     71.60        83
# 3         Isangel      VU  1540672256 -19.55  169.27     75.02       100
# 4            Kosa      RU  1540672535  59.94   54.99     33.67        78
#
#    Cloudiness  Wind Speed
# 0           0        4.70
# 1          90       11.41
# 2           0        7.07
# 3           0        1.92
# 4          76       16.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Max Temp"],
            marker="o", alpha=.7, edgecolors='black')

# Incorporate the other graph properties

plt.title(f"City Latitude vs Max Temperature {actual_date}")

plt.ylabel("Max Temperature (F)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsTemp.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Humidity"],
            marker="o", alpha=.7, edgecolors='black')

# Incorporate the other graph properties

plt.title(f"City Latitude vs Humidity {actual_date}")

plt.ylabel("Humidity(%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsHumidity.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Cloudiness"],
            marker="o", alpha=.7, edgecolors='black')

# Incorporate the other graph properties

plt.title(f"City Latitude vs Cloudiness {actual_date}")

plt.ylabel("Cloudiness(%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsCloudiness.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_data["Lat"], weather_data["Wind Speed"],
            marker="o", alpha=.7, edgecolors='black')

# Incorporate the other graph properties

plt.title(f"City Latitude vs Wind Speed {actual_date}")

plt.ylabel("Wind Speed (mph)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("../Images/LatitudeVsWindSpeed.png")

# Show plot

plt.show()

# %% [markdown]
# ### Conclusion
# * The weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude).
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
